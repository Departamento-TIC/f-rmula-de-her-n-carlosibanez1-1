# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/f-rmula-de-her-n-carlosibanez1-1/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
#Pedimos el valor entero de cada uno de los lados
ladoA =int(input("cuanto mide el primer lado:"))
ladoB =int(input("cuanto mide el segundo lado:"))
ladoC =int(input("cuanto mide el tercer lado:"))

#Cálculo del semiperímetro
s=(ladoA+ladoB+ladoC)/2
#Cálculo del área
area=(s*(s-ladoA)*(s-ladoB)*(s-ladoC))**(1/2)
#Imprimimos el resultado
print('el semiperimetro es=',s)
print('el area es=',area)
# Out:
# cuanto mide el primer lado:2
# cuanto mide el segundo lado:2
# cuanto mide el tercer lado:2
# el semiperimetro es= 3.0
# el area es= 1.7320508075688772
